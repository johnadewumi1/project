# %%
import numpy as np
import pandas as pd
from datetime import datetime

# %%
Sales_df=pd.read_excel(r'C:\Users\johna\OneDrive\Desktop\Sales.xls')
Sales_df.head()
# Out:
#    Row ID  Order ID Order Date  Column1  Column2  Column3  Orderdate  \
# 0       1         3    ~40464%  ~40464%   40464%    40464 2010-10-13
# 1      49       293    ~41183%  ~41183%   41183%    41183 2012-10-01
# 2      50       293    ~41183%  ~41183%   41183%    41183 2012-10-01
# 3      80       483    ~40734%  ~40734%   40734%    40734 2011-07-10
# 4      85       515    ~40418%  ~40418%   40418%    40418 2010-08-28
#
#   Order Priority  Column4  Column5  ...  Last Name   Region  Customer Segment  \
# 0            Low        6        1  ...  MacIntyre  Nunavut    Small Business
# 1           High       18        2  ...     French  Nunavut          Consumer
# 2           High       27        1  ...     French  Nunavut          Consumer
# 3           High       30        1  ...   Rozendal  Nunavut         Corporate
# 4  Not Specified       19        1  ...    Soltero  Nunavut          Consumer
#
#    Product Category            Product Sub-Category  \
# 0   Office Supplies          Storage & Organization
# 1   Office Supplies                      Appliances
# 2   Office Supplies  Binders and Binder Accessories
# 3        Technology    Telephones and Communication
# 4   Office Supplies                      Appliances
#
#                                         Product Name  Product Container  \
# 0   Eldon Base for stackable storage shelf, platinum          Large Box
# 1  1.7 Cubic Foot Compact "Cube" Office Refrigera...         Jumbo Drum
# 2   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl          Small Box
# 3                                               R380          Small Box
# 4                           Holmes HEPA Air Purifier         Medium Box
#
#    Product Base Margin   Ship Date   BirthDate
# 0                 0.80  20/10/2010  08/04/1970
# 1                 0.58  02/10/2012  14/05/1969
# 2                 0.39  03/10/2012  12/08/1969
# 3                 0.58  12/07/2011  15/02/1972
# 4                 0.50  30/08/2010  08/08/1972
#
# [5 rows x 30 columns]

# %%
Sales_df.describe()
# Out:
#             Row ID      Order ID       Column3      Column4      Column5  \
# count  8399.000000   8399.000000   8399.000000  8399.000000  8399.000000
# mean   4200.000000  29965.179783  40537.028456    13.775569     1.380521
# std    2424.726789  17260.883447    423.491286     8.399965     0.485544
# min       1.000000      3.000000  39814.000000     1.000000     1.000000
# 25%    2100.500000  15011.500000  40167.000000     7.000000     1.000000
# 50%    4200.000000  29857.000000  40529.000000    13.000000     1.000000
# 75%    6299.500000  44596.000000  40909.500000    19.000000     2.000000
# max    8399.000000  59973.000000  41273.000000    31.000000     2.000000
#
#        Column6  Orderquantity         Sales     Discount        Profit  \
# count   8399.0    8399.000000   8399.000000  8399.000000   8399.000000
# mean    1900.0      25.571735   1775.878179     0.049671    181.184424
# std        0.0      14.481071   3585.050525     0.031823   1196.653371
# min     1900.0       1.000000      2.240000     0.000000 -14140.700000
# 25%     1900.0      13.000000    143.195000     0.020000    -83.315000
# 50%     1900.0      26.000000    449.420000     0.050000     -1.500000
# 75%     1900.0      38.000000   1709.320000     0.080000    162.750000
# max     1900.0      50.000000  89061.050000     0.250000  27220.690000
#
#         Unit Price  Shipping Cost  Product Base Margin
# count  8399.000000    8399.000000          8336.000000
# mean     89.346259      12.838557             0.512513
# std     290.354383      17.264052             0.135589
# min       0.990000       0.490000             0.350000
# 25%       6.480000       3.300000             0.380000
# 50%      20.990000       6.070000             0.520000
# 75%      85.990000      13.990000             0.590000
# max    6783.020000     164.730000             0.850000

# %%
Sales_df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Column1', 'Column2', 'Column3',
#        'Orderdate', 'Order Priority', 'Column4', 'Column5', 'Column6',
#        'Column7', 'Orderquantity', 'Sales', 'Discount', 'Ship Mode', 'Profit',
#        'Unit Price', 'Shipping Cost', 'First Name', 'Last Name', 'Region',
#        'Customer Segment', 'Product Category', 'Product Sub-Category',
#        'Product Name', 'Product Container', 'Product Base Margin', 'Ship Date',
#        'BirthDate'],
#       dtype='object')

# %%
Sales_df.drop(['Column1','Column2','Column3','Column4','Column5','Column6',
       'Column7'],axis='columns',inplace=True)

# %%
Sales_df.head()
# Out:
#    Row ID  Order ID Order Date  Orderdate Order Priority  Orderquantity  \
# 0       1         3    ~40464% 2010-10-13            Low              6
# 1      49       293    ~41183% 2012-10-01           High             49
# 2      50       293    ~41183% 2012-10-01           High             27
# 3      80       483    ~40734% 2011-07-10           High             30
# 4      85       515    ~40418% 2010-08-28  Not Specified             19
#
#         Sales  Discount       Ship Mode   Profit  ...  Last Name   Region  \
# 0    261.5400      0.04     Regular Air  -213.25  ...  MacIntyre  Nunavut
# 1  10123.0200      0.07  Delivery Truck   457.81  ...     French  Nunavut
# 2    244.5700      0.01     Regular Air    46.71  ...     French  Nunavut
# 3   4965.7595      0.08     Regular Air  1198.97  ...   Rozendal  Nunavut
# 4    394.2700      0.08     Regular Air    30.94  ...    Soltero  Nunavut
#
#   Customer Segment Product Category            Product Sub-Category  \
# 0   Small Business  Office Supplies          Storage & Organization
# 1         Consumer  Office Supplies                      Appliances
# 2         Consumer  Office Supplies  Binders and Binder Accessories
# 3        Corporate       Technology    Telephones and Communication
# 4         Consumer  Office Supplies                      Appliances
#
#                                         Product Name Product Container  \
# 0   Eldon Base for stackable storage shelf, platinum         Large Box
# 1  1.7 Cubic Foot Compact "Cube" Office Refrigera...        Jumbo Drum
# 2   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl         Small Box
# 3                                               R380         Small Box
# 4                           Holmes HEPA Air Purifier        Medium Box
#
#   Product Base Margin   Ship Date   BirthDate
# 0                0.80  20/10/2010  08/04/1970
# 1                0.58  02/10/2012  14/05/1969
# 2                0.39  03/10/2012  12/08/1969
# 3                0.58  12/07/2011  15/02/1972
# 4                0.50  30/08/2010  08/08/1972
#
# [5 rows x 23 columns]

# %%
#changing Birthday and Ship date to real time date
Sales_df['Ship Date']=Sales_df['Ship Date'].str.replace(r'\W','')
Sales_df['BirthDate']=Sales_df['BirthDate'].str.replace(r'\W','')
Sales_df['Order Date']=Sales_df['Order Date'].str.replace(r'\W','')

# %%
from datetime import datetime

Sales_df['Ship Date'] =pd.to_datetime(Sales_df['Ship Date'],format='%d%m%Y')
Sales_df['BirthDate']=pd.to_datetime(Sales_df['BirthDate'],format='%d%m%Y')

#Alternatively
# Sales_df['Ship Date']=pd.to_datetime(Sales_df['Ship Date'])
# Sales_df.head()
# Sales_df['BirthDate']=pd.to_datetime(Sales_df['BirthDate'])
# Sales_df

# %%
Sales_df.head()
# Out:
#    Row ID  Order ID Order Date  Orderdate Order Priority  Orderquantity  \
# 0       1         3      40464 2010-10-13            Low              6
# 1      49       293      41183 2012-10-01           High             49
# 2      50       293      41183 2012-10-01           High             27
# 3      80       483      40734 2011-07-10           High             30
# 4      85       515      40418 2010-08-28  Not Specified             19
#
#         Sales  Discount       Ship Mode   Profit  ...  Last Name   Region  \
# 0    261.5400      0.04     Regular Air  -213.25  ...  MacIntyre  Nunavut
# 1  10123.0200      0.07  Delivery Truck   457.81  ...     French  Nunavut
# 2    244.5700      0.01     Regular Air    46.71  ...     French  Nunavut
# 3   4965.7595      0.08     Regular Air  1198.97  ...   Rozendal  Nunavut
# 4    394.2700      0.08     Regular Air    30.94  ...    Soltero  Nunavut
#
#   Customer Segment Product Category            Product Sub-Category  \
# 0   Small Business  Office Supplies          Storage & Organization
# 1         Consumer  Office Supplies                      Appliances
# 2         Consumer  Office Supplies  Binders and Binder Accessories
# 3        Corporate       Technology    Telephones and Communication
# 4         Consumer  Office Supplies                      Appliances
#
#                                         Product Name Product Container  \
# 0   Eldon Base for stackable storage shelf, platinum         Large Box
# 1  1.7 Cubic Foot Compact "Cube" Office Refrigera...        Jumbo Drum
# 2   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl         Small Box
# 3                                               R380         Small Box
# 4                           Holmes HEPA Air Purifier        Medium Box
#
#   Product Base Margin  Ship Date  BirthDate
# 0                0.80 2010-10-20 1970-04-08
# 1                0.58 2012-10-02 1969-05-14
# 2                0.39 2012-10-03 1969-08-12
# 3                0.58 2011-07-12 1972-02-15
# 4                0.50 2010-08-30 1972-08-08
#
# [5 rows x 23 columns]

# %%
Sales_df[['Ship Date','BirthDate']] #we need to convert this to real datetime
# Out:
#       Ship Date  BirthDate
# 0    2010-10-20 1970-04-08
# 1    2012-10-02 1969-05-14
# 2    2012-10-03 1969-08-12
# 3    2011-07-12 1972-02-15
# 4    2010-08-30 1972-08-08
# ...         ...        ...
# 8394 2010-08-09 1965-06-16
# 8395 2010-08-11 1964-06-01
# 8396 2011-04-10 1964-03-11
# 8397 2011-04-09 1964-08-27
# 8398 2009-02-11 1964-10-09
#
# [8399 rows x 2 columns]

# %%
Sales_df[['Ship Date','BirthDate']].dtypes
# Out:
# Ship Date    datetime64[ns]
# BirthDate    datetime64[ns]
# dtype: object

# %%
year=Sales_df['Orderdate'].dt.year
month=Sales_df['Orderdate'].dt.month
day=Sales_df['Orderdate'].dt.day

# %%
Sales_df.insert(4,'Year',list(year),True)
Sales_df.insert(5,'Month',list(month),True)
Sales_df.insert(6,'Day',list(day),True)

# %%
Sales_df.head()
# Out:
#    Row ID  Order ID Order Date  Orderdate  Year  Month  Day Order Priority  \
# 0       1         3      40464 2010-10-13  2010     10   13            Low
# 1      49       293      41183 2012-10-01  2012     10    1           High
# 2      50       293      41183 2012-10-01  2012     10    1           High
# 3      80       483      40734 2011-07-10  2011      7   10           High
# 4      85       515      40418 2010-08-28  2010      8   28  Not Specified
#
#    Orderquantity       Sales  ...  Last Name   Region  Customer Segment  \
# 0              6    261.5400  ...  MacIntyre  Nunavut    Small Business
# 1             49  10123.0200  ...     French  Nunavut          Consumer
# 2             27    244.5700  ...     French  Nunavut          Consumer
# 3             30   4965.7595  ...   Rozendal  Nunavut         Corporate
# 4             19    394.2700  ...    Soltero  Nunavut          Consumer
#
#    Product Category            Product Sub-Category  \
# 0   Office Supplies          Storage & Organization
# 1   Office Supplies                      Appliances
# 2   Office Supplies  Binders and Binder Accessories
# 3        Technology    Telephones and Communication
# 4   Office Supplies                      Appliances
#
#                                         Product Name Product Container  \
# 0   Eldon Base for stackable storage shelf, platinum         Large Box
# 1  1.7 Cubic Foot Compact "Cube" Office Refrigera...        Jumbo Drum
# 2   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl         Small Box
# 3                                               R380         Small Box
# 4                           Holmes HEPA Air Purifier        Medium Box
#
#   Product Base Margin  Ship Date  BirthDate
# 0                0.80 2010-10-20 1970-04-08
# 1                0.58 2012-10-02 1969-05-14
# 2                0.39 2012-10-03 1969-08-12
# 3                0.58 2011-07-12 1972-02-15
# 4                0.50 2010-08-30 1972-08-08
#
# [5 rows x 26 columns]

# %%
Sales_df['Year'].dtypes
# Out:
# dtype('int64')

# %%
pd.Series.dt.strftime
yearmonth=Sales_df['Orderdate'].dt.strftime('%Y-%m')
yearmonth
# Out:
# 0       2010-10
# 1       2012-10
# 2       2012-10
# 3       2011-07
# 4       2010-08
#          ...
# 8394    2010-08
# 8395    2010-08
# 8396    2011-04
# 8397    2011-04
# 8398    2009-02
# Name: Orderdate, Length: 8399, dtype: object

# %%
Sales_df.insert(7,'YearMonth',list(yearmonth),True)

# %%
Sales_df
# Out:
#       Row ID  Order ID Order Date  Orderdate  Year  Month  Day YearMonth  \
# 0          1         3      40464 2010-10-13  2010     10   13   2010-10
# 1         49       293      41183 2012-10-01  2012     10    1   2012-10
# 2         50       293      41183 2012-10-01  2012     10    1   2012-10
# 3         80       483      40734 2011-07-10  2011      7   10   2011-07
# 4         85       515      40418 2010-08-28  2010      8   28   2010-08
# ...      ...       ...        ...        ...   ...    ...  ...       ...
# 8394    7765     55558      40399 2010-08-09  2010      8    9   2010-08
# 8395    7766     55558      40399 2010-08-09  2010      8    9   2010-08
# 8396    7906     56550      40641 2011-04-08  2011      4    8   2011-04
# 8397    7907     56550      40641 2011-04-08  2011      4    8   2011-04
# 8398    7914     56581      39852 2009-02-08  2009      2    8   2009-02
#
#      Order Priority  Orderquantity  ...  Last Name   Region Customer Segment  \
# 0               Low              6  ...  MacIntyre  Nunavut   Small Business
# 1              High             49  ...     French  Nunavut         Consumer
# 2              High             27  ...     French  Nunavut         Consumer
# 3              High             30  ...   Rozendal  Nunavut        Corporate
# 4     Not Specified             19  ...    Soltero  Nunavut         Consumer
# ...             ...            ...  ...        ...      ...              ...
# 8394         Medium              8  ...      Brown     West         Consumer
# 8395         Medium             23  ...      Brown     West         Consumer
# 8396  Not Specified             37  ...     Hawley     West      Home Office
# 8397  Not Specified              8  ...     Hawley     West      Home Office
# 8398           High             20  ...  Donatelli     West         Consumer
#
#       Product Category            Product Sub-Category  \
# 0      Office Supplies          Storage & Organization
# 1      Office Supplies                      Appliances
# 2      Office Supplies  Binders and Binder Accessories
# 3           Technology    Telephones and Communication
# 4      Office Supplies                      Appliances
# ...                ...                             ...
# 8394         Furniture                       Bookcases
# 8395   Office Supplies                       Envelopes
# 8396         Furniture              Office Furnishings
# 8397        Technology    Telephones and Communication
# 8398         Furniture              Office Furnishings
#
#                                            Product Name Product Container  \
# 0      Eldon Base for stackable storage shelf, platinum         Large Box
# 1     1.7 Cubic Foot Compact "Cube" Office Refrigera...        Jumbo Drum
# 2      Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl         Small Box
# 3                                                  R380         Small Box
# 4                              Holmes HEPA Air Purifier        Medium Box
# ...                                                 ...               ...
# 8394                        Bush Mission Pointe Library         Jumbo Box
# 8395  Recycled Interoffice Envelopes with Re-Use-A-S...         Small Box
# 8396                          Executive Impressions 14"        Small Pack
# 8397                                    Talkabout T8367         Small Box
# 8398  Tenex 46" x 60" Computer Anti-Static Chairmat,...        Medium Box
#
#      Product Base Margin  Ship Date  BirthDate
# 0                   0.80 2010-10-20 1970-04-08
# 1                   0.58 2012-10-02 1969-05-14
# 2                   0.39 2012-10-03 1969-08-12
# 3                   0.58 2011-07-12 1972-02-15
# 4                   0.50 2010-08-30 1972-08-08
# ...                  ...        ...        ...
# 8394                0.65 2010-08-09 1965-06-16
# 8395                0.38 2010-08-11 1964-06-01
# 8396                0.41 2011-04-10 1964-03-11
# 8397                0.56 2011-04-09 1964-08-27
# 8398                0.65 2009-02-11 1964-10-09
#
# [8399 rows x 27 columns]

# %%
#pupulating the manager table to merge with the sales dataframe so as to get the Manager name pupulated on the sales dataset
manager_df=pd.read_excel(r'C:\Users\johna\OneDrive\Desktop\Manager.xls')
manager_df
# Out:
#                   Region  Manager
# 0                Nunavut    Chris
# 1  Northwest Territories     Erin
# 2               Atlantic      Sam
# 3                 Prarie  William
# 4                   West      Pat
# 5                Ontario      Pat
# 6                 Quebec      Pat
# 7                  Yukon      Pat

# %%
#Merge sales_df and Manager _df 
SALES=pd.merge(Sales_df,manager_df,how='inner',on='Region')
SALES.head()
# Out:
#    Row ID  Order ID Order Date  Orderdate  Year  Month  Day YearMonth  \
# 0       1         3      40464 2010-10-13  2010     10   13   2010-10
# 1      49       293      41183 2012-10-01  2012     10    1   2012-10
# 2      50       293      41183 2012-10-01  2012     10    1   2012-10
# 3      80       483      40734 2011-07-10  2011      7   10   2011-07
# 4      85       515      40418 2010-08-28  2010      8   28   2010-08
#
#   Order Priority  Orderquantity  ...   Region  Customer Segment  \
# 0            Low              6  ...  Nunavut    Small Business
# 1           High             49  ...  Nunavut          Consumer
# 2           High             27  ...  Nunavut          Consumer
# 3           High             30  ...  Nunavut         Corporate
# 4  Not Specified             19  ...  Nunavut          Consumer
#
#   Product Category            Product Sub-Category  \
# 0  Office Supplies          Storage & Organization
# 1  Office Supplies                      Appliances
# 2  Office Supplies  Binders and Binder Accessories
# 3       Technology    Telephones and Communication
# 4  Office Supplies                      Appliances
#
#                                         Product Name  Product Container  \
# 0   Eldon Base for stackable storage shelf, platinum          Large Box
# 1  1.7 Cubic Foot Compact "Cube" Office Refrigera...         Jumbo Drum
# 2   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl          Small Box
# 3                                               R380          Small Box
# 4                           Holmes HEPA Air Purifier         Medium Box
#
#   Product Base Margin  Ship Date  BirthDate Manager
# 0                0.80 2010-10-20 1970-04-08   Chris
# 1                0.58 2012-10-02 1969-05-14   Chris
# 2                0.39 2012-10-03 1969-08-12   Chris
# 3                0.58 2011-07-12 1972-02-15   Chris
# 4                0.50 2010-08-30 1972-08-08   Chris
#
# [5 rows x 28 columns]

# %%
# inserting the Mnaager name to the position asfter the Region
SALES.insert(16,'ManagerName',list(SALES['Manager']),True)

# %%
SALES.head()
# Out:
#    Row ID  Order ID Order Date  Orderdate  Year  Month  Day YearMonth  \
# 0       1         3      40464 2010-10-13  2010     10   13   2010-10
# 1      49       293      41183 2012-10-01  2012     10    1   2012-10
# 2      50       293      41183 2012-10-01  2012     10    1   2012-10
# 3      80       483      40734 2011-07-10  2011      7   10   2011-07
# 4      85       515      40418 2010-08-28  2010      8   28   2010-08
#
#   Order Priority  Orderquantity  ...   Region  Customer Segment  \
# 0            Low              6  ...  Nunavut    Small Business
# 1           High             49  ...  Nunavut          Consumer
# 2           High             27  ...  Nunavut          Consumer
# 3           High             30  ...  Nunavut         Corporate
# 4  Not Specified             19  ...  Nunavut          Consumer
#
#   Product Category            Product Sub-Category  \
# 0  Office Supplies          Storage & Organization
# 1  Office Supplies                      Appliances
# 2  Office Supplies  Binders and Binder Accessories
# 3       Technology    Telephones and Communication
# 4  Office Supplies                      Appliances
#
#                                         Product Name  Product Container  \
# 0   Eldon Base for stackable storage shelf, platinum          Large Box
# 1  1.7 Cubic Foot Compact "Cube" Office Refrigera...         Jumbo Drum
# 2   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl          Small Box
# 3                                               R380          Small Box
# 4                           Holmes HEPA Air Purifier         Medium Box
#
#   Product Base Margin  Ship Date  BirthDate Manager
# 0                0.80 2010-10-20 1970-04-08   Chris
# 1                0.58 2012-10-02 1969-05-14   Chris
# 2                0.39 2012-10-03 1969-08-12   Chris
# 3                0.58 2011-07-12 1972-02-15   Chris
# 4                0.50 2010-08-30 1972-08-08   Chris
#
# [5 rows x 29 columns]

# %%
sales_tran=SALES
sales_tran.head()
# Out:
#    Row ID  Order ID Order Date  Orderdate  Year  Month  Day YearMonth  \
# 0       1         3      40464 2010-10-13  2010     10   13   2010-10
# 1      49       293      41183 2012-10-01  2012     10    1   2012-10
# 2      50       293      41183 2012-10-01  2012     10    1   2012-10
# 3      80       483      40734 2011-07-10  2011      7   10   2011-07
# 4      85       515      40418 2010-08-28  2010      8   28   2010-08
#
#   Order Priority  Orderquantity  ...   Region  Customer Segment  \
# 0            Low              6  ...  Nunavut    Small Business
# 1           High             49  ...  Nunavut          Consumer
# 2           High             27  ...  Nunavut          Consumer
# 3           High             30  ...  Nunavut         Corporate
# 4  Not Specified             19  ...  Nunavut          Consumer
#
#   Product Category            Product Sub-Category  \
# 0  Office Supplies          Storage & Organization
# 1  Office Supplies                      Appliances
# 2  Office Supplies  Binders and Binder Accessories
# 3       Technology    Telephones and Communication
# 4  Office Supplies                      Appliances
#
#                                         Product Name  Product Container  \
# 0   Eldon Base for stackable storage shelf, platinum          Large Box
# 1  1.7 Cubic Foot Compact "Cube" Office Refrigera...         Jumbo Drum
# 2   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl          Small Box
# 3                                               R380          Small Box
# 4                           Holmes HEPA Air Purifier         Medium Box
#
#   Product Base Margin  Ship Date  BirthDate Manager
# 0                0.80 2010-10-20 1970-04-08   Chris
# 1                0.58 2012-10-02 1969-05-14   Chris
# 2                0.39 2012-10-03 1969-08-12   Chris
# 3                0.58 2011-07-12 1972-02-15   Chris
# 4                0.50 2010-08-30 1972-08-08   Chris
#
# [5 rows x 29 columns]

# %%
sales_tran.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Orderdate', 'Year', 'Month', 'Day',
#        'YearMonth', 'Order Priority', 'Orderquantity', 'Sales', 'Discount',
#        'Ship Mode', 'Profit', 'Unit Price', 'Shipping Cost', 'ManagerName',
#        'First Name', 'Last Name', 'Region', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Name',
#        'Product Container', 'Product Base Margin', 'Ship Date', 'BirthDate',
#        'Manager'],
#       dtype='object')

# %%
sales_tran.drop(['Order Date','Manager'],axis='columns',inplace=True)

# %%
sales_tran.head()
# Out:
#    Row ID  Order ID  Orderdate  Year  Month  Day YearMonth Order Priority  \
# 0       1         3 2010-10-13  2010     10   13   2010-10            Low
# 1      49       293 2012-10-01  2012     10    1   2012-10           High
# 2      50       293 2012-10-01  2012     10    1   2012-10           High
# 3      80       483 2011-07-10  2011      7   10   2011-07           High
# 4      85       515 2010-08-28  2010      8   28   2010-08  Not Specified
#
#    Orderquantity       Sales  ...  Last Name   Region  Customer Segment  \
# 0              6    261.5400  ...  MacIntyre  Nunavut    Small Business
# 1             49  10123.0200  ...     French  Nunavut          Consumer
# 2             27    244.5700  ...     French  Nunavut          Consumer
# 3             30   4965.7595  ...   Rozendal  Nunavut         Corporate
# 4             19    394.2700  ...    Soltero  Nunavut          Consumer
#
#    Product Category            Product Sub-Category  \
# 0   Office Supplies          Storage & Organization
# 1   Office Supplies                      Appliances
# 2   Office Supplies  Binders and Binder Accessories
# 3        Technology    Telephones and Communication
# 4   Office Supplies                      Appliances
#
#                                         Product Name Product Container  \
# 0   Eldon Base for stackable storage shelf, platinum         Large Box
# 1  1.7 Cubic Foot Compact "Cube" Office Refrigera...        Jumbo Drum
# 2   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl         Small Box
# 3                                               R380         Small Box
# 4                           Holmes HEPA Air Purifier        Medium Box
#
#   Product Base Margin  Ship Date  BirthDate
# 0                0.80 2010-10-20 1970-04-08
# 1                0.58 2012-10-02 1969-05-14
# 2                0.39 2012-10-03 1969-08-12
# 3                0.58 2011-07-12 1972-02-15
# 4                0.50 2010-08-30 1972-08-08
#
# [5 rows x 27 columns]

# %%
fullname=sales_tran['First Name']+' '+sales_tran['Last Name']

# %%
sales_tran.insert(14,'FullName',list(fullname),True)

# %%
sales_tran.head()
# Out:
#    Row ID  Order ID  Orderdate  Year  Month  Day YearMonth Order Priority  \
# 0       1         3 2010-10-13  2010     10   13   2010-10            Low
# 1      49       293 2012-10-01  2012     10    1   2012-10           High
# 2      50       293 2012-10-01  2012     10    1   2012-10           High
# 3      80       483 2011-07-10  2011      7   10   2011-07           High
# 4      85       515 2010-08-28  2010      8   28   2010-08  Not Specified
#
#    Orderquantity       Sales  ...  Last Name   Region  Customer Segment  \
# 0              6    261.5400  ...  MacIntyre  Nunavut    Small Business
# 1             49  10123.0200  ...     French  Nunavut          Consumer
# 2             27    244.5700  ...     French  Nunavut          Consumer
# 3             30   4965.7595  ...   Rozendal  Nunavut         Corporate
# 4             19    394.2700  ...    Soltero  Nunavut          Consumer
#
#    Product Category            Product Sub-Category  \
# 0   Office Supplies          Storage & Organization
# 1   Office Supplies                      Appliances
# 2   Office Supplies  Binders and Binder Accessories
# 3        Technology    Telephones and Communication
# 4   Office Supplies                      Appliances
#
#                                         Product Name Product Container  \
# 0   Eldon Base for stackable storage shelf, platinum         Large Box
# 1  1.7 Cubic Foot Compact "Cube" Office Refrigera...        Jumbo Drum
# 2   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl         Small Box
# 3                                               R380         Small Box
# 4                           Holmes HEPA Air Purifier        Medium Box
#
#   Product Base Margin  Ship Date  BirthDate
# 0                0.80 2010-10-20 1970-04-08
# 1                0.58 2012-10-02 1969-05-14
# 2                0.39 2012-10-03 1969-08-12
# 3                0.58 2011-07-12 1972-02-15
# 4                0.50 2010-08-30 1972-08-08
#
# [5 rows x 28 columns]

# %%
#calling the priority dataframe
priority_df=pd.read_excel(r'C:\Users\johna\OneDrive\Desktop\Priority.xls')
priority_df
# Out:
#   Order Priority  Priority code
# 0       Critical              5
# 1           High              4
# 2         Medium              3
# 3            Low              2
# 4  Not Specified              1

# %%
#merge prioritydf with sales_tran
sales_dff=pd.merge(sales_tran,priority_df,on='Order Priority',how='inner')
sales_dff
# Out:
#       Row ID  Order ID  Orderdate  Year  Month  Day YearMonth Order Priority  \
# 0          1         3 2010-10-13  2010     10   13   2010-10            Low
# 1        107       678 2010-02-26  2010      2   26   2010-02            Low
# 2        203      1344 2012-04-15  2012      4   15   2012-04            Low
# 3        204      1344 2012-04-15  2012      4   15   2012-04            Low
# 4        229      1539 2011-03-09  2011      3    9   2011-03            Low
# ...      ...       ...        ...   ...    ...  ...       ...            ...
# 8394    4065     28933 2009-07-09  2009      7    9   2009-07       Critical
# 8395    4198     29831 2012-03-29  2012      3   29   2012-03       Critical
# 8396    4336     30887 2010-07-07  2010      7    7   2010-07       Critical
# 8397    4433     31590 2010-06-05  2010      6    5   2010-06       Critical
# 8398    4434     31590 2010-06-05  2010      6    5   2010-06       Critical
#
#       Orderquantity      Sales  ...   Region Customer Segment  \
# 0                 6   261.5400  ...  Nunavut   Small Business
# 1                44   228.4100  ...  Nunavut      Home Office
# 2                15   834.9040  ...  Nunavut        Corporate
# 3                18  2480.9205  ...  Nunavut        Corporate
# 4                33   511.8300  ...  Nunavut        Corporate
# ...             ...        ...  ...      ...              ...
# 8394             38   156.2000  ...    Yukon        Corporate
# 8395             29  2175.2200  ...    Yukon   Small Business
# 8396             44  4357.1170  ...    Yukon      Home Office
# 8397              5    43.4900  ...    Yukon        Corporate
# 8398             27  2854.7600  ...    Yukon        Corporate
#
#       Product Category            Product Sub-Category  \
# 0      Office Supplies          Storage & Organization
# 1      Office Supplies                           Paper
# 2           Technology    Telephones and Communication
# 3           Technology    Telephones and Communication
# 4      Office Supplies  Binders and Binder Accessories
# ...                ...                             ...
# 8394   Office Supplies             Pens & Art Supplies
# 8395   Office Supplies                      Appliances
# 8396        Technology    Telephones and Communication
# 8397        Technology            Computer Peripherals
# 8398   Office Supplies          Storage & Organization
#
#                                            Product Name  Product Container  \
# 0      Eldon Base for stackable storage shelf, platinum          Large Box
# 1                                             Xerox 198          Small Box
# 2                                                  g520          Small Box
# 3                                                LX 788          Small Box
# 4     GBC Pre-Punched Binding Paper, Plastic, White,...          Small Box
# ...                                                 ...                ...
# 8394                      4009® Highlighters by Sanford           Wrap Bag
# 8395  Holmes Replacement Filter for HEPA Air Cleaner...         Jumbo Drum
# 8396                                               8890          Small Box
# 8397  80 Minute Slim Jewel Case CD-R , 10/Pack - Sta...         Small Pack
# 8398                  Fellowes Recycled Storage Drawers          Small Box
#
#      Product Base Margin  Ship Date  BirthDate Priority code
# 0                   0.80 2010-10-20 1970-04-08             2
# 1                   0.38 2010-02-26        NaT             2
# 2                   0.59 2012-04-22 1982-03-07             2
# 3                   0.58 2012-04-19 1982-09-20             2
# 4                   0.37 2011-03-11 1982-10-11             2
# ...                  ...        ...        ...           ...
# 8394                0.52 2009-07-10 1973-06-10             5
# 8395                0.41 2012-03-30 1956-06-22             5
# 8396                0.58 2010-07-07 1972-10-27             5
# 8397                0.52 2010-06-06 1971-09-08             5
# 8398                0.78 2010-06-07 1971-07-04             5
#
# [8399 rows x 29 columns]

# %%
sales_dff.insert(8,'PriorityCode',list(sales_dff['Priority code']),True)

# %%
sales_dff.drop(['Priority code'],axis='columns',inplace=True)

# %%
sales_dff.head()
# Out:
#    Row ID  Order ID  Orderdate  Year  Month  Day YearMonth Order Priority  \
# 0       1         3 2010-10-13  2010     10   13   2010-10            Low
# 1     107       678 2010-02-26  2010      2   26   2010-02            Low
# 2     203      1344 2012-04-15  2012      4   15   2012-04            Low
# 3     204      1344 2012-04-15  2012      4   15   2012-04            Low
# 4     229      1539 2011-03-09  2011      3    9   2011-03            Low
#
#    PriorityCode  Orderquantity  ...  Last Name   Region Customer Segment  \
# 0             2              6  ...  MacIntyre  Nunavut   Small Business
# 1             2             44  ...    Badders  Nunavut      Home Office
# 2             2             15  ...    Radford  Nunavut        Corporate
# 3             2             18  ...    Radford  Nunavut        Corporate
# 4             2             33  ...     Ludwig  Nunavut        Corporate
#
#    Product Category            Product Sub-Category  \
# 0   Office Supplies          Storage & Organization
# 1   Office Supplies                           Paper
# 2        Technology    Telephones and Communication
# 3        Technology    Telephones and Communication
# 4   Office Supplies  Binders and Binder Accessories
#
#                                         Product Name  Product Container  \
# 0   Eldon Base for stackable storage shelf, platinum          Large Box
# 1                                          Xerox 198          Small Box
# 2                                               g520          Small Box
# 3                                             LX 788          Small Box
# 4  GBC Pre-Punched Binding Paper, Plastic, White,...          Small Box
#
#   Product Base Margin  Ship Date  BirthDate
# 0                0.80 2010-10-20 1970-04-08
# 1                0.38 2010-02-26        NaT
# 2                0.59 2012-04-22 1982-03-07
# 3                0.58 2012-04-19 1982-09-20
# 4                0.37 2011-03-11 1982-10-11
#
# [5 rows x 29 columns]

# %%
#calling the return dataframe
return_df=pd.read_excel(r'C:\Users\johna\OneDrive\Desktop\return.xls')
return_df
# Out:
#      Order ID    Status
# 0          65  Returned
# 1          69  Returned
# 2         134  Returned
# 3         135  Returned
# 4         230  Returned
# ..        ...       ...
# 567     59680  Returned
# 568     59683  Returned
# 569     59776  Returned
# 570     59879  Returned
# 571     59937  Returned
#
# [572 rows x 2 columns]

# %%
#merge the return with the salestransaction
sales_d=pd.merge(sales_dff,return_df,on='Order ID',how='outer')
sales_d.head()
# Out:
#    Row ID  Order ID  Orderdate  Year  Month  Day YearMonth Order Priority  \
# 0       1         3 2010-10-13  2010     10   13   2010-10            Low
# 1     107       678 2010-02-26  2010      2   26   2010-02            Low
# 2     203      1344 2012-04-15  2012      4   15   2012-04            Low
# 3     204      1344 2012-04-15  2012      4   15   2012-04            Low
# 4     229      1539 2011-03-09  2011      3    9   2011-03            Low
#
#    PriorityCode  Orderquantity  ...   Region  Customer Segment  \
# 0             2              6  ...  Nunavut    Small Business
# 1             2             44  ...  Nunavut       Home Office
# 2             2             15  ...  Nunavut         Corporate
# 3             2             18  ...  Nunavut         Corporate
# 4             2             33  ...  Nunavut         Corporate
#
#   Product Category            Product Sub-Category  \
# 0  Office Supplies          Storage & Organization
# 1  Office Supplies                           Paper
# 2       Technology    Telephones and Communication
# 3       Technology    Telephones and Communication
# 4  Office Supplies  Binders and Binder Accessories
#
#                                         Product Name Product Container  \
# 0   Eldon Base for stackable storage shelf, platinum         Large Box
# 1                                          Xerox 198         Small Box
# 2                                               g520         Small Box
# 3                                             LX 788         Small Box
# 4  GBC Pre-Punched Binding Paper, Plastic, White,...         Small Box
#
#    Product Base Margin  Ship Date  BirthDate    Status
# 0                 0.80 2010-10-20 1970-04-08       NaN
# 1                 0.38 2010-02-26        NaT  Returned
# 2                 0.59 2012-04-22 1982-03-07       NaN
# 3                 0.58 2012-04-19 1982-09-20       NaN
# 4                 0.37 2011-03-11 1982-10-11       NaN
#
# [5 rows x 30 columns]

# %%
#inserting the satus to the right position
sales_d.insert(2,'OrderStatus',list(sales_d['Status']),True)

# %%
sales_d.drop('Status',axis='columns',inplace=True)

# %%
sales_d.head()
# Out:
#    Row ID  Order ID OrderStatus  Orderdate  Year  Month  Day YearMonth  \
# 0       1         3         NaN 2010-10-13  2010     10   13   2010-10
# 1     107       678    Returned 2010-02-26  2010      2   26   2010-02
# 2     203      1344         NaN 2012-04-15  2012      4   15   2012-04
# 3     204      1344         NaN 2012-04-15  2012      4   15   2012-04
# 4     229      1539         NaN 2011-03-09  2011      3    9   2011-03
#
#   Order Priority  PriorityCode  ...  Last Name   Region  Customer Segment  \
# 0            Low             2  ...  MacIntyre  Nunavut    Small Business
# 1            Low             2  ...    Badders  Nunavut       Home Office
# 2            Low             2  ...    Radford  Nunavut         Corporate
# 3            Low             2  ...    Radford  Nunavut         Corporate
# 4            Low             2  ...     Ludwig  Nunavut         Corporate
#
#   Product Category            Product Sub-Category  \
# 0  Office Supplies          Storage & Organization
# 1  Office Supplies                           Paper
# 2       Technology    Telephones and Communication
# 3       Technology    Telephones and Communication
# 4  Office Supplies  Binders and Binder Accessories
#
#                                         Product Name Product Container  \
# 0   Eldon Base for stackable storage shelf, platinum         Large Box
# 1                                          Xerox 198         Small Box
# 2                                               g520         Small Box
# 3                                             LX 788         Small Box
# 4  GBC Pre-Punched Binding Paper, Plastic, White,...         Small Box
#
#    Product Base Margin  Ship Date  BirthDate
# 0                 0.80 2010-10-20 1970-04-08
# 1                 0.38 2010-02-26        NaT
# 2                 0.59 2012-04-22 1982-03-07
# 3                 0.58 2012-04-19 1982-09-20
# 4                 0.37 2011-03-11 1982-10-11
#
# [5 rows x 30 columns]

# %%
#Creating calculated filed
SalesPerunit=sales_d['Sales']/sales_d['Orderquantity']
ProfitPerUnit=sales_d['Profit']/sales_d['Orderquantity']
UnitPricePerUnit=sales_d['Unit Price']/sales_d['Orderquantity']

# %%
sales_d.columns
# Out:
# Index(['Row ID', 'Order ID', 'OrderStatus', 'Orderdate', 'Year', 'Month',
#        'Day', 'YearMonth', 'Order Priority', 'PriorityCode', 'Orderquantity',
#        'Sales', 'Discount', 'Ship Mode', 'Profit', 'Unit Price', 'FullName',
#        'Shipping Cost', 'ManagerName', 'First Name', 'Last Name', 'Region',
#        'Customer Segment', 'Product Category', 'Product Sub-Category',
#        'Product Name', 'Product Container', 'Product Base Margin', 'Ship Date',
#        'BirthDate'],
#       dtype='object')

# %%
sales_d.insert(12,'SalesPerunit',list(SalesPerunit),True)
sales_d.insert(16,'ProfitPerUnit',list(ProfitPerUnit),True)
sales_d.insert(18,'UnitPricePerUnit',list(UnitPricePerUnit),True)

# %%
sales_d.head()
# Out:
#    Row ID  Order ID OrderStatus  Orderdate  Year  Month  Day YearMonth  \
# 0       1         3         NaN 2010-10-13  2010     10   13   2010-10
# 1     107       678    Returned 2010-02-26  2010      2   26   2010-02
# 2     203      1344         NaN 2012-04-15  2012      4   15   2012-04
# 3     204      1344         NaN 2012-04-15  2012      4   15   2012-04
# 4     229      1539         NaN 2011-03-09  2011      3    9   2011-03
#
#   Order Priority  PriorityCode  ...  Last Name   Region  Customer Segment  \
# 0            Low             2  ...  MacIntyre  Nunavut    Small Business
# 1            Low             2  ...    Badders  Nunavut       Home Office
# 2            Low             2  ...    Radford  Nunavut         Corporate
# 3            Low             2  ...    Radford  Nunavut         Corporate
# 4            Low             2  ...     Ludwig  Nunavut         Corporate
#
#    Product Category            Product Sub-Category  \
# 0   Office Supplies          Storage & Organization
# 1   Office Supplies                           Paper
# 2        Technology    Telephones and Communication
# 3        Technology    Telephones and Communication
# 4   Office Supplies  Binders and Binder Accessories
#
#                                         Product Name  Product Container  \
# 0   Eldon Base for stackable storage shelf, platinum          Large Box
# 1                                          Xerox 198          Small Box
# 2                                               g520          Small Box
# 3                                             LX 788          Small Box
# 4  GBC Pre-Punched Binding Paper, Plastic, White,...          Small Box
#
#    Product Base Margin  Ship Date  BirthDate
# 0                 0.80 2010-10-20 1970-04-08
# 1                 0.38 2010-02-26        NaT
# 2                 0.59 2012-04-22 1982-03-07
# 3                 0.58 2012-04-19 1982-09-20
# 4                 0.37 2011-03-11 1982-10-11
#
# [5 rows x 33 columns]

# %%
sales_d.dtypes
# Out:
# Row ID                           int64
# Order ID                         int64
# OrderStatus                     object
# Orderdate               datetime64[ns]
# Year                             int64
# Month                            int64
# Day                              int64
# YearMonth                       object
# Order Priority                  object
# PriorityCode                     int64
# Orderquantity                    int64
# Sales                          float64
# SalesPerunit                   float64
# Discount                       float64
# Ship Mode                       object
# Profit                         float64
# ProfitPerUnit                  float64
# Unit Price                     float64
# UnitPricePerUnit               float64
# FullName                        object
# Shipping Cost                  float64
# ManagerName                     object
# First Name                      object
# Last Name                       object
# Region                          object
# Customer Segment                object
# Product Category                object
# Product Sub-Category            object
# Product Name                    object
# Product Container               object
# Product Base Margin            float64
# Ship Date               datetime64[ns]
# BirthDate               datetime64[ns]
# dtype: object

# %%
Year=sales_d['BirthDate'].dt.year
Year
# Out:
# 0       1970.0
# 1          NaN
# 2       1982.0
# 3       1982.0
# 4       1982.0
#          ...
# 8394    1973.0
# 8395    1956.0
# 8396    1972.0
# 8397    1971.0
# 8398    1971.0
# Name: BirthDate, Length: 8399, dtype: float64

# %%
#Calculation the Real Age
import datetime
RealAge=datetime.datetime.now().year - Year
RealAge
# Out:
# 0       50.0
# 1        NaN
# 2       38.0
# 3       38.0
# 4       38.0
#         ...
# 8394    47.0
# 8395    64.0
# 8396    48.0
# 8397    49.0
# 8398    49.0
# Name: BirthDate, Length: 8399, dtype: float64

# %%
#Creating the Age column
sales_d['AGE']=RealAge
sales_d.head()
# Out:
#    Row ID  Order ID OrderStatus  Orderdate  Year  Month  Day YearMonth  \
# 0       1         3         NaN 2010-10-13  2010     10   13   2010-10
# 1     107       678    Returned 2010-02-26  2010      2   26   2010-02
# 2     203      1344         NaN 2012-04-15  2012      4   15   2012-04
# 3     204      1344         NaN 2012-04-15  2012      4   15   2012-04
# 4     229      1539         NaN 2011-03-09  2011      3    9   2011-03
#
#   Order Priority  PriorityCode  ...   Region  Customer Segment  \
# 0            Low             2  ...  Nunavut    Small Business
# 1            Low             2  ...  Nunavut       Home Office
# 2            Low             2  ...  Nunavut         Corporate
# 3            Low             2  ...  Nunavut         Corporate
# 4            Low             2  ...  Nunavut         Corporate
#
#    Product Category            Product Sub-Category  \
# 0   Office Supplies          Storage & Organization
# 1   Office Supplies                           Paper
# 2        Technology    Telephones and Communication
# 3        Technology    Telephones and Communication
# 4   Office Supplies  Binders and Binder Accessories
#
#                                         Product Name  Product Container  \
# 0   Eldon Base for stackable storage shelf, platinum          Large Box
# 1                                          Xerox 198          Small Box
# 2                                               g520          Small Box
# 3                                             LX 788          Small Box
# 4  GBC Pre-Punched Binding Paper, Plastic, White,...          Small Box
#
#    Product Base Margin  Ship Date  BirthDate   AGE
# 0                 0.80 2010-10-20 1970-04-08  50.0
# 1                 0.38 2010-02-26        NaT   NaN
# 2                 0.59 2012-04-22 1982-03-07  38.0
# 3                 0.58 2012-04-19 1982-09-20  38.0
# 4                 0.37 2011-03-11 1982-10-11  38.0
#
# [5 rows x 34 columns]

# %%
# #Replacing the null values in the AGE with NA
# sales_d['AGE'].fillna(value='NA',inplace=True)

# %%
sales_d.head()
# Out:
#    Row ID  Order ID OrderStatus  Orderdate  Year  Month  Day YearMonth  \
# 0       1         3         NaN 2010-10-13  2010     10   13   2010-10
# 1     107       678    Returned 2010-02-26  2010      2   26   2010-02
# 2     203      1344         NaN 2012-04-15  2012      4   15   2012-04
# 3     204      1344         NaN 2012-04-15  2012      4   15   2012-04
# 4     229      1539         NaN 2011-03-09  2011      3    9   2011-03
#
#   Order Priority  PriorityCode  ...   Region  Customer Segment  \
# 0            Low             2  ...  Nunavut    Small Business
# 1            Low             2  ...  Nunavut       Home Office
# 2            Low             2  ...  Nunavut         Corporate
# 3            Low             2  ...  Nunavut         Corporate
# 4            Low             2  ...  Nunavut         Corporate
#
#    Product Category            Product Sub-Category  \
# 0   Office Supplies          Storage & Organization
# 1   Office Supplies                           Paper
# 2        Technology    Telephones and Communication
# 3        Technology    Telephones and Communication
# 4   Office Supplies  Binders and Binder Accessories
#
#                                         Product Name  Product Container  \
# 0   Eldon Base for stackable storage shelf, platinum          Large Box
# 1                                          Xerox 198          Small Box
# 2                                               g520          Small Box
# 3                                             LX 788          Small Box
# 4  GBC Pre-Punched Binding Paper, Plastic, White,...          Small Box
#
#    Product Base Margin  Ship Date  BirthDate   AGE
# 0                 0.80 2010-10-20 1970-04-08  50.0
# 1                 0.38 2010-02-26        NaT   NaN
# 2                 0.59 2012-04-22 1982-03-07  38.0
# 3                 0.58 2012-04-19 1982-09-20  38.0
# 4                 0.37 2011-03-11 1982-10-11  38.0
#
# [5 rows x 34 columns]

# %%
#Replacing the null values in Orderstatus with NA
sales_d['OrderStatus'].fillna(value='Delivered',inplace=True)

# %%
sales_d
# Out:
#       Row ID  Order ID OrderStatus  Orderdate  Year  Month  Day YearMonth  \
# 0          1         3   Delivered 2010-10-13  2010     10   13   2010-10
# 1        107       678    Returned 2010-02-26  2010      2   26   2010-02
# 2        203      1344   Delivered 2012-04-15  2012      4   15   2012-04
# 3        204      1344   Delivered 2012-04-15  2012      4   15   2012-04
# 4        229      1539   Delivered 2011-03-09  2011      3    9   2011-03
# ...      ...       ...         ...        ...   ...    ...  ...       ...
# 8394    4065     28933   Delivered 2009-07-09  2009      7    9   2009-07
# 8395    4198     29831   Delivered 2012-03-29  2012      3   29   2012-03
# 8396    4336     30887   Delivered 2010-07-07  2010      7    7   2010-07
# 8397    4433     31590   Delivered 2010-06-05  2010      6    5   2010-06
# 8398    4434     31590   Delivered 2010-06-05  2010      6    5   2010-06
#
#      Order Priority  PriorityCode  ...   Region  Customer Segment  \
# 0               Low             2  ...  Nunavut    Small Business
# 1               Low             2  ...  Nunavut       Home Office
# 2               Low             2  ...  Nunavut         Corporate
# 3               Low             2  ...  Nunavut         Corporate
# 4               Low             2  ...  Nunavut         Corporate
# ...             ...           ...  ...      ...               ...
# 8394       Critical             5  ...    Yukon         Corporate
# 8395       Critical             5  ...    Yukon    Small Business
# 8396       Critical             5  ...    Yukon       Home Office
# 8397       Critical             5  ...    Yukon         Corporate
# 8398       Critical             5  ...    Yukon         Corporate
#
#       Product Category            Product Sub-Category  \
# 0      Office Supplies          Storage & Organization
# 1      Office Supplies                           Paper
# 2           Technology    Telephones and Communication
# 3           Technology    Telephones and Communication
# 4      Office Supplies  Binders and Binder Accessories
# ...                ...                             ...
# 8394   Office Supplies             Pens & Art Supplies
# 8395   Office Supplies                      Appliances
# 8396        Technology    Telephones and Communication
# 8397        Technology            Computer Peripherals
# 8398   Office Supplies          Storage & Organization
#
#                                            Product Name  Product Container  \
# 0      Eldon Base for stackable storage shelf, platinum          Large Box
# 1                                             Xerox 198          Small Box
# 2                                                  g520          Small Box
# 3                                                LX 788          Small Box
# 4     GBC Pre-Punched Binding Paper, Plastic, White,...          Small Box
# ...                                                 ...                ...
# 8394                      4009® Highlighters by Sanford           Wrap Bag
# 8395  Holmes Replacement Filter for HEPA Air Cleaner...         Jumbo Drum
# 8396                                               8890          Small Box
# 8397  80 Minute Slim Jewel Case CD-R , 10/Pack - Sta...         Small Pack
# 8398                  Fellowes Recycled Storage Drawers          Small Box
#
#       Product Base Margin  Ship Date  BirthDate   AGE
# 0                    0.80 2010-10-20 1970-04-08  50.0
# 1                    0.38 2010-02-26        NaT   NaN
# 2                    0.59 2012-04-22 1982-03-07  38.0
# 3                    0.58 2012-04-19 1982-09-20  38.0
# 4                    0.37 2011-03-11 1982-10-11  38.0
# ...                   ...        ...        ...   ...
# 8394                 0.52 2009-07-10 1973-06-10  47.0
# 8395                 0.41 2012-03-30 1956-06-22  64.0
# 8396                 0.58 2010-07-07 1972-10-27  48.0
# 8397                 0.52 2010-06-06 1971-09-08  49.0
# 8398                 0.78 2010-06-07 1971-07-04  49.0
#
# [8399 rows x 34 columns]

# %%
sales_d.isnull().sum()
# Out:
# Row ID                   0
# Order ID                 0
# OrderStatus              0
# Orderdate                0
# Year                     0
# Month                    0
# Day                      0
# YearMonth                0
# Order Priority           0
# PriorityCode             0
# Orderquantity            0
# Sales                    0
# SalesPerunit             0
# Discount                 0
# Ship Mode               30
# Profit                   0
# ProfitPerUnit            0
# Unit Price               0
# UnitPricePerUnit         0
# FullName                 0
# Shipping Cost            0
# ManagerName              0
# First Name               0
# Last Name                0
# Region                   0
# Customer Segment         0
# Product Category         0
# Product Sub-Category     0
# Product Name             0
# Product Container        0
# Product Base Margin     63
# Ship Date                0
# BirthDate               30
# AGE                     30
# dtype: int64

# %%
#Erasing the null values 
sales_d['Product Base Margin'].fillna(value='NA',inplace=True)
sales_d['BirthDate'].fillna(value='NA',inplace=True)
sales_d['Ship Mode'].fillna(value='NA',inplace=True)

# %%
sales_d.head()
# Out:
#    Row ID  Order ID OrderStatus  Orderdate  Year  Month  Day YearMonth  \
# 0       1         3   Delivered 2010-10-13  2010     10   13   2010-10
# 1     107       678    Returned 2010-02-26  2010      2   26   2010-02
# 2     203      1344   Delivered 2012-04-15  2012      4   15   2012-04
# 3     204      1344   Delivered 2012-04-15  2012      4   15   2012-04
# 4     229      1539   Delivered 2011-03-09  2011      3    9   2011-03
#
#   Order Priority  PriorityCode  ...   Region  Customer Segment  \
# 0            Low             2  ...  Nunavut    Small Business
# 1            Low             2  ...  Nunavut       Home Office
# 2            Low             2  ...  Nunavut         Corporate
# 3            Low             2  ...  Nunavut         Corporate
# 4            Low             2  ...  Nunavut         Corporate
#
#    Product Category            Product Sub-Category  \
# 0   Office Supplies          Storage & Organization
# 1   Office Supplies                           Paper
# 2        Technology    Telephones and Communication
# 3        Technology    Telephones and Communication
# 4   Office Supplies  Binders and Binder Accessories
#
#                                         Product Name  Product Container  \
# 0   Eldon Base for stackable storage shelf, platinum          Large Box
# 1                                          Xerox 198          Small Box
# 2                                               g520          Small Box
# 3                                             LX 788          Small Box
# 4  GBC Pre-Punched Binding Paper, Plastic, White,...          Small Box
#
#    Product Base Margin  Ship Date            BirthDate   AGE
# 0                  0.8 2010-10-20  1970-04-08 00:00:00  50.0
# 1                 0.38 2010-02-26                   NA   NaN
# 2                 0.59 2012-04-22  1982-03-07 00:00:00  38.0
# 3                 0.58 2012-04-19  1982-09-20 00:00:00  38.0
# 4                 0.37 2011-03-11  1982-10-11 00:00:00  38.0
#
# [5 rows x 34 columns]

# %%
sales_d.isnull().sum().sum()
# Out:
# 30

# %%
sales_d['AGE']
# Out:
# 0       50.0
# 1        NaN
# 2       38.0
# 3       38.0
# 4       38.0
#         ...
# 8394    47.0
# 8395    64.0
# 8396    48.0
# 8397    49.0
# 8398    49.0
# Name: AGE, Length: 8399, dtype: float64

# %%
# x=sales_d['AGE']

# def Ageband(x):
#     if x>=30 and x<45:
#         return '30'
#     elif  x>=45 and x<60:
#         return '45'
#     elif  x>=60 and x<75:
#         return '60'
#     elif  x>=75 and x<90:
#         return '75'
#     elif  x>=90 and x<105:
#         return '90'
#     elif x>=105 and x<120:
#         return '105'
#     else:
#         return 'NA'

# Ageband(x)

# %%
# score=float(input(x))
# if x>=30 and x<45:
#     print('30-44')
# elif  x>=45 and x<60:
#     print('45-59')
# elif  x>=60 and x<75:
#     print('60-74')
# elif  x>=75 and x<90:
#      print('75-89')
# elif  x>=90 and x<105:
#     print('90-104')
# else:
#     print('105-119')

# %%
# #CREATING THE AGEBAND
# list1={'AGE':[30,45,60,75,90,105],
#        'AGEBAND':['30-44','45-59','60-74','75-89','90-104','105-119']}
# list2=pd.DataFrame(list1)
# list2

# %%
# #CREATING THE AGE BAND COLUMN
# pd.merge(sales_d,list2,how='outer',on='AGE',False)

# %%
#Calculation the agregate functions
print(sales_d.Profit.mean())
print(sales_d.Sales.mean())
# Out:
# 181.18442433622988
# 1775.878178830812

# %%
Shipping_Mean=sales_d['Shipping Cost'].mean()
Shipping_Mean
# Out:
# 12.838556971068233

# %%
#Cal Manager performance
Manager_count=sales_d['ManagerName'].value_counts()
Manager_count
# Out:
# Pat        5140
# William    1706
# Sam        1080
# Erin        394
# Chris        79
# Name: ManagerName, dtype: int64

# %%
Manager_ct=Manager_count.to_frame().reset_index()
Manager_ct
# Out:
#      index  ManagerName
# 0      Pat         5140
# 1  William         1706
# 2      Sam         1080
# 3     Erin          394
# 4    Chris           79

# %%
Manager_ct.columns=["Managername","Transactions"]

# %%
Manager_ct
# Out:
#   Managername  Transactions
# 0         Pat          5140
# 1     William          1706
# 2         Sam          1080
# 3        Erin           394
# 4       Chris            79

# %%
X=Manager_ct['Managername']
Y=Manager_ct['Transactions']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.bar(X,Y,label='Performnace',color='purple')
plt.xlabel('Manager')
plt.ylabel('Counts')
plt.legend()
plt.title('Managers Performance Chart')
plt.show()

# %%
Prioritycount=sales_d['Order Priority'].value_counts()
Prioritycount
# Out:
# High             1768
# Low              1720
# Not Specified    1672
# Medium           1631
# Critical         1608
# Name: Order Priority, dtype: int64

# %%
Priority_ct=Prioritycount.to_frame().reset_index()
Priority_ct
Priority_ct.columns=['OrderPriority','Occurrences']
Priority_ct
# Out:
#    OrderPriority  Occurrences
# 0           High         1768
# 1            Low         1720
# 2  Not Specified         1672
# 3         Medium         1631
# 4       Critical         1608

# %%
a=Priority_ct['OrderPriority']
b=Priority_ct['Occurrences']

# %%
plt.bar(a,b,label='Counting',color='green')
plt.xlabel('OrderPriority')
plt.ylabel('Occurrences')
plt.legend()
plt.title('Order Priority Chart')
plt.show()

# %%
e=sales_d['Day']
f=sales_d['Profit']

# %%
plt.bar(e,f,label='Daysrevenue',color='brown')
plt.xlabel('Days')
plt.ylabel('Profit')
plt.legend()
plt.title('Days Revenue Chat')
plt.show()

# %%
daysrevnue=sns.jointplot(e,f,color='orange',kind='scatter')

# %% [markdown]
# # CALCULATING DAYS TAKEN TO SHIP

# %%
#CALCULATING DAYS TAKEN TO SHIP
daystoship=sales_d['Ship Date']-sales_d['Orderdate']
daystoship
# Out:
# 0      7 days
# 1      0 days
# 2      7 days
# 3      4 days
# 4      2 days
#         ...
# 8394   1 days
# 8395   1 days
# 8396   0 days
# 8397   1 days
# 8398   2 days
# Length: 8399, dtype: timedelta64[ns]

# %%
print(daystoship.mean())
print(daystoship.max())
print(daystoship.min())
print(daystoship.median())
print(daystoship.mode())
# Out:
# 2 days 00:47:50.055959
# 92 days 00:00:00
# 0 days 00:00:00
# 2 days 00:00:00
# 0   2 days
# dtype: timedelta64[ns]

# %% [markdown]
# # GROUP WITH THE MAX COUNTS

# %%
#PROUCT CATEGORY MAX
prod=sales_d['Product Category'].value_counts()
prod
# Out:
# Office Supplies    4610
# Technology         2065
# Furniture          1724
# Name: Product Category, dtype: int64

# %%
#REGION CATEGORY MAX
Reg=sales_d['Region'].value_counts()
Reg
# Out:
# West                     1991
# Ontario                  1826
# Prarie                   1706
# Atlantic                 1080
# Quebec                    781
# Yukon                     542
# Northwest Territories     394
# Nunavut                    79
# Name: Region, dtype: int64

# %%
#CUSTOMER CATEGORY MAX
Cus=sales_d['Customer Segment'].value_counts()
Cus
# Out:
# Corporate         3076
# Home Office       2032
# Consumer          1649
# Small Business    1642
# Name: Customer Segment, dtype: int64

# %%
Prod=sales_d['Product Sub-Category'].value_counts()
Prod
# Out:
# Paper                             1225
# Binders and Binder Accessories     915
# Telephones and Communication       883
# Office Furnishings                 788
# Computer Peripherals               758
# Pens & Art Supplies                633
# Storage & Organization             546
# Appliances                         434
# Chairs & Chairmats                 386
# Tables                             361
# Office Machines                    337
# Labels                             288
# Envelopes                          246
# Bookcases                          189
# Rubber Bands                       179
# Scissors, Rulers and Trimmers      144
# Copiers and Fax                     87
# Name: Product Sub-Category, dtype: int64

# %% [markdown]
# # CALCULATION THE SECTION WITH HIGHEST PROFIT

# %%
sales_d.groupby('Product Category')['Profit'].sum()
# Out:
# Product Category
# Furniture          117433.03
# Office Supplies    518021.43
# Technology         886313.52
# Name: Profit, dtype: float64

# %%
sales_d.groupby('Region')['Profit'].sum()
# Out:
# Region
# Atlantic                 238960.66
# Northwest Territories    100653.08
# Nunavut                    2841.11
# Ontario                  346868.54
# Prarie                   321160.12
# Quebec                   140426.65
# West                     297008.61
# Yukon                     73849.21
# Name: Profit, dtype: float64

# %%
sales_d.groupby('Customer Segment')['Profit'].sum()
# Out:
# Customer Segment
# Consumer          287959.94
# Corporate         599746.00
# Home Office       318354.03
# Small Business    315708.01
# Name: Profit, dtype: float64

# %%
#SUBTITUITING DAYS TO SHIP IN THE DATASET


sales_d['DAYS']=daystoship

# %%
sales_d.head()
# Out:
#    Row ID  Order ID OrderStatus  Orderdate  Year  Month  Day YearMonth  \
# 0       1         3   Delivered 2010-10-13  2010     10   13   2010-10
# 1     107       678    Returned 2010-02-26  2010      2   26   2010-02
# 2     203      1344   Delivered 2012-04-15  2012      4   15   2012-04
# 3     204      1344   Delivered 2012-04-15  2012      4   15   2012-04
# 4     229      1539   Delivered 2011-03-09  2011      3    9   2011-03
#
#   Order Priority  PriorityCode  ...  Customer Segment  Product Category  \
# 0            Low             2  ...    Small Business   Office Supplies
# 1            Low             2  ...       Home Office   Office Supplies
# 2            Low             2  ...         Corporate        Technology
# 3            Low             2  ...         Corporate        Technology
# 4            Low             2  ...         Corporate   Office Supplies
#
#              Product Sub-Category  \
# 0          Storage & Organization
# 1                           Paper
# 2    Telephones and Communication
# 3    Telephones and Communication
# 4  Binders and Binder Accessories
#
#                                         Product Name Product Container  \
# 0   Eldon Base for stackable storage shelf, platinum         Large Box
# 1                                          Xerox 198         Small Box
# 2                                               g520         Small Box
# 3                                             LX 788         Small Box
# 4  GBC Pre-Punched Binding Paper, Plastic, White,...         Small Box
#
#    Product Base Margin  Ship Date            BirthDate   AGE   DAYS
# 0                  0.8 2010-10-20  1970-04-08 00:00:00  50.0 7 days
# 1                 0.38 2010-02-26                   NA   NaN 0 days
# 2                 0.59 2012-04-22  1982-03-07 00:00:00  38.0 7 days
# 3                 0.58 2012-04-19  1982-09-20 00:00:00  38.0 4 days
# 4                 0.37 2011-03-11  1982-10-11 00:00:00  38.0 2 days
#
# [5 rows x 35 columns]

# %%
#CREATING THE DAYS COLUM TO ONLY HAVE THE INTEGER
sales_d['DAYS']=sales_d['DAYS'].astype('str')
# sales_d['DAYS']=sales_d['DAYS'].str.replace(r'\W','')
# sales_d['DAYS']

set1=sales_d['DAYS'].str.split(' ',expand=True)
set1
# Out:
#       0     1                   2
# 0     7  days  00:00:00.000000000
# 1     0  days  00:00:00.000000000
# 2     7  days  00:00:00.000000000
# 3     4  days  00:00:00.000000000
# 4     2  days  00:00:00.000000000
# ...  ..   ...                 ...
# 8394  1  days  00:00:00.000000000
# 8395  1  days  00:00:00.000000000
# 8396  0  days  00:00:00.000000000
# 8397  1  days  00:00:00.000000000
# 8398  2  days  00:00:00.000000000
#
# [8399 rows x 3 columns]

# %%
sales_d['DAYS']=set1[0]
sales_d['DAYS']
# Out:
# 0       7
# 1       0
# 2       7
# 3       4
# 4       2
#        ..
# 8394    1
# 8395    1
# 8396    0
# 8397    1
# 8398    2
# Name: DAYS, Length: 8399, dtype: object

# %% [markdown]
# # TO CALCULATE WORSE OFFENDDR MANAGER THAT HAS CRITICAL
# # ORDER THAT TOOK LONGER DAYS TO SHIP

# %%
sales_new=sales_d[(sales_d['DAYS']>'2 days') & (sales_d['Order Priority']=='Critical')]
sales_new
# Out:
#       Row ID  Order ID OrderStatus  Orderdate  Year  Month  Day YearMonth  \
# 377     1068      7878   Delivered 2011-05-01  2011      5    1   2011-05
# 880     7943     56740   Delivered 2012-10-16  2012     10   16   2012-10
# 1118    7199     51361   Delivered 2011-03-18  2011      3   18   2011-03
# 1343    1455     10470   Delivered 2012-05-04  2012      5    4   2012-05
# 6809     911      6535   Delivered 2012-06-12  2012      6   12   2012-06
# ...      ...       ...         ...        ...   ...    ...  ...       ...
# 8318    5785     41056   Delivered 2012-03-26  2012      3   26   2012-03
# 8345    1145      8325   Delivered 2009-01-14  2009      1   14   2009-01
# 8368    2819     20325   Delivered 2010-07-03  2010      7    3   2010-07
# 8369    2833     20450   Delivered 2012-12-07  2012     12    7   2012-12
# 8378    3194     22913   Delivered 2010-06-25  2010      6   25   2010-06
#
#      Order Priority  PriorityCode  ...  Customer Segment  Product Category  \
# 377        Critical             5  ...         Corporate         Furniture
# 880        Critical             5  ...          Consumer         Furniture
# 1118       Critical             5  ...         Corporate         Furniture
# 1343       Critical             5  ...         Corporate         Furniture
# 6809       Critical             5  ...         Corporate   Office Supplies
# ...             ...           ...  ...               ...               ...
# 8318       Critical             5  ...    Small Business        Technology
# 8345       Critical             5  ...       Home Office   Office Supplies
# 8368       Critical             5  ...    Small Business   Office Supplies
# 8369       Critical             5  ...       Home Office         Furniture
# 8378       Critical             5  ...         Corporate         Furniture
#
#       Product Sub-Category                                       Product Name  \
# 377              Bookcases            O'Sullivan 5-Shelf Heavy-Duty Bookcases
# 880     Office Furnishings                             Flat Face Poster Frame
# 1118                Tables  SAFCO PlanMaster Heigh-Adjustable Drafting Tab...
# 1343    Office Furnishings     Eldon® Expressions™ Wood Desk Accessories, Oak
# 6809   Pens & Art Supplies  Boston Electric Pencil Sharpener, Model 1818, ...
# ...                    ...                                                ...
# 8318  Computer Peripherals                   Fellowes EZ Multi-Media Keyboard
# 8345   Pens & Art Supplies                                         Newell 336
# 8368   Pens & Art Supplies  Dixon Ticonderoga Core-Lock Colored Pencils, 4...
# 8369                Tables            Bevis Round Bullnose 29" High Table Top
# 8378                Tables      Bretford CR4500 Series Slim Rectangular Table
#
#      Product Container  Product Base Margin  Ship Date            BirthDate  \
# 377          Jumbo Box                  0.6 2011-05-06  1983-03-14 00:00:00
# 880           Wrap Bag                 0.43 2012-10-23  1958-11-13 00:00:00
# 1118        Jumbo Drum                   NA 2011-03-22  1975-01-09 00:00:00
# 1343         Small Box                 0.56 2012-05-09  1950-10-12 00:00:00
# 6809        Small Pack                 0.57 2012-06-15  1979-04-07 00:00:00
# ...                ...                  ...        ...                  ...
# 8318         Small Box                 0.76 2012-03-29  1966-03-07 00:00:00
# 8345          Wrap Bag                 0.56 2009-01-17  1963-01-23 00:00:00
# 8368          Wrap Bag                 0.41 2010-07-06  1979-10-24 00:00:00
# 8369         Jumbo Box                 0.61 2012-12-10  1978-03-01 00:00:00
# 8378         Jumbo Box                 0.62 2010-06-28  1939-09-03 00:00:00
#
#        AGE DAYS
# 377   37.0    5
# 880   62.0    7
# 1118  45.0    4
# 1343  70.0    5
# 6809  41.0    3
# ...    ...  ...
# 8318  54.0    3
# 8345  57.0    3
# 8368  41.0    3
# 8369  42.0    3
# 8378  81.0    3
#
# [108 rows x 35 columns]

# %%
sales_new['ManagerName'].value_counts()
# Out:
# Pat        64
# William    27
# Sam        10
# Erin        6
# Chris       1
# Name: ManagerName, dtype: int64

# %%
manager_crit=sales_new['ManagerName'].value_counts().to_frame().reset_index()
manager_crit
# Out:
#      index  ManagerName
# 0      Pat           64
# 1  William           27
# 2      Sam           10
# 3     Erin            6
# 4    Chris            1

# %%
manager_crit.columns=['Manager','Counts']
manager_crit
# Out:
#    Manager  Counts
# 0      Pat      64
# 1  William      27
# 2      Sam      10
# 3     Erin       6
# 4    Chris       1

# %%
x=manager_crit['Manager']
y=manager_crit['Counts']

# %%
plt.bar(x,y,label='Underperform',color='brown')
plt.xlabel('Manager')
plt.ylabel('Count')
plt.legend()
plt.title('Managers Critical Chart')
plt.show()

# %% [markdown]
# #TO CALCULATE HOW MANY CRITICAL ORDER THAT TOOK LONGER DAYS TO SHIP

# %%
sales_new['Product Category'].value_counts()
# Out:
# Office Supplies    62
# Furniture          25
# Technology         21
# Name: Product Category, dtype: int64

# %%
Product_crit=sales_new['Product Category'].value_counts().to_frame().reset_index()
Product_crit
# Out:
#              index  Product Category
# 0  Office Supplies                62
# 1        Furniture                25
# 2       Technology                21

# %%
Product_crit.columns=['Category','Count']
Product_crit
# Out:
#           Category  Count
# 0  Office Supplies     62
# 1        Furniture     25
# 2       Technology     21

# %%
c=Product_crit['Category']
d=Product_crit['Count']

# %%
plt.bar(c,d,label='Underperform',color='blue')
plt.xlabel('Category')
plt.ylabel('Count')
plt.legend()
plt.title('Product Critical Chart')
plt.show()

# %% [markdown]
# # TO CALCULATE SUM OF PROFIT ON RETURNED ORDER

# %%
Sales_returned=sales_d[sales_d['OrderStatus']=='Returned']
Sales_returned.head()
# Out:
#     Row ID  Order ID OrderStatus  Orderdate  Year  Month  Day YearMonth  \
# 1      107       678    Returned 2010-02-26  2010      2   26   2010-02
# 24    1770     12704    Returned 2010-02-09  2010      2    9   2010-02
# 25    1771     12704    Returned 2010-02-09  2010      2    9   2010-02
# 32    2624     19010    Returned 2009-06-07  2009      6    7   2009-06
# 33    2643     19138    Returned 2011-09-05  2011      9    5   2011-09
#
#    Order Priority  PriorityCode  ...  Customer Segment  Product Category  \
# 1             Low             2  ...       Home Office   Office Supplies
# 24            Low             2  ...    Small Business        Technology
# 25            Low             2  ...    Small Business   Office Supplies
# 32            Low             2  ...    Small Business   Office Supplies
# 33            Low             2  ...       Home Office   Office Supplies
#
#               Product Sub-Category  \
# 1                            Paper
# 24                 Copiers and Fax
# 25          Storage & Organization
# 32  Binders and Binder Accessories
# 33          Storage & Organization
#
#                                          Product Name Product Container  \
# 1                                           Xerox 198         Small Box
# 24                     Sharp AL-1530CS Digital Copier         Large Box
# 25                              Tennsco Lockers, Gray        Jumbo Drum
# 32  Fellowes PB500 Electric Punch Plastic Comb Bin...         Small Box
# 33             Recycled Eldon Regeneration Jumbo File         Small Box
#
#     Product Base Margin  Ship Date            BirthDate   AGE DAYS
# 1                  0.38 2010-02-26                   NA   NaN    0
# 24                 0.36 2010-02-09  1966-02-12 00:00:00  54.0    0
# 25                 0.78 2010-02-11  1966-10-07 00:00:00  54.0    2
# 32                 0.35 2009-06-09  1967-03-05 00:00:00  53.0    2
# 33                 0.57 2011-09-10  1946-07-04 00:00:00  74.0    5
#
# [5 rows x 35 columns]

# %%
Sales_returned.groupby('OrderStatus')['Profit'].sum()
# Out:
# OrderStatus
# Returned    198432.9
# Name: Profit, dtype: float64

# %% [markdown]
# # TO CALCULATE SUM OF PROFIT ON DELIVERED ORDER

# %%
Sales_delivered=sales_d[sales_d['OrderStatus']=='Delivered']
Sales_delivered.head()
# Out:
#    Row ID  Order ID OrderStatus  Orderdate  Year  Month  Day YearMonth  \
# 0       1         3   Delivered 2010-10-13  2010     10   13   2010-10
# 2     203      1344   Delivered 2012-04-15  2012      4   15   2012-04
# 3     204      1344   Delivered 2012-04-15  2012      4   15   2012-04
# 4     229      1539   Delivered 2011-03-09  2011      3    9   2011-03
# 5     230      1539   Delivered 2011-03-09  2011      3    9   2011-03
#
#   Order Priority  PriorityCode  ...  Customer Segment  Product Category  \
# 0            Low             2  ...    Small Business   Office Supplies
# 2            Low             2  ...         Corporate        Technology
# 3            Low             2  ...         Corporate        Technology
# 4            Low             2  ...         Corporate   Office Supplies
# 5            Low             2  ...         Corporate        Technology
#
#              Product Sub-Category  \
# 0          Storage & Organization
# 2    Telephones and Communication
# 3    Telephones and Communication
# 4  Binders and Binder Accessories
# 5            Computer Peripherals
#
#                                         Product Name Product Container  \
# 0   Eldon Base for stackable storage shelf, platinum         Large Box
# 2                                               g520         Small Box
# 3                                             LX 788         Small Box
# 4  GBC Pre-Punched Binding Paper, Plastic, White,...         Small Box
# 5  Maxell 3.5" DS/HD IBM-Formatted Diskettes, 10/...        Small Pack
#
#    Product Base Margin  Ship Date            BirthDate   AGE DAYS
# 0                  0.8 2010-10-20  1970-04-08 00:00:00  50.0    7
# 2                 0.59 2012-04-22  1982-03-07 00:00:00  38.0    7
# 3                 0.58 2012-04-19  1982-09-20 00:00:00  38.0    4
# 4                 0.37 2011-03-11  1982-10-11 00:00:00  38.0    2
# 5                 0.66 2011-03-14  1982-09-17 00:00:00  38.0    5
#
# [5 rows x 35 columns]

# %%
Sales_delivered.groupby('OrderStatus')['Profit'].sum()
# Out:
# OrderStatus
# Delivered    1323335.08
# Name: Profit, dtype: float64

# %%
sales_d
# Out:
#       Row ID  Order ID OrderStatus  Orderdate  Year  Month  Day YearMonth  \
# 0          1         3   Delivered 2010-10-13  2010     10   13   2010-10
# 1        107       678    Returned 2010-02-26  2010      2   26   2010-02
# 2        203      1344   Delivered 2012-04-15  2012      4   15   2012-04
# 3        204      1344   Delivered 2012-04-15  2012      4   15   2012-04
# 4        229      1539   Delivered 2011-03-09  2011      3    9   2011-03
# ...      ...       ...         ...        ...   ...    ...  ...       ...
# 8394    4065     28933   Delivered 2009-07-09  2009      7    9   2009-07
# 8395    4198     29831   Delivered 2012-03-29  2012      3   29   2012-03
# 8396    4336     30887   Delivered 2010-07-07  2010      7    7   2010-07
# 8397    4433     31590   Delivered 2010-06-05  2010      6    5   2010-06
# 8398    4434     31590   Delivered 2010-06-05  2010      6    5   2010-06
#
#      Order Priority  PriorityCode  ...  Customer Segment  Product Category  \
# 0               Low             2  ...    Small Business   Office Supplies
# 1               Low             2  ...       Home Office   Office Supplies
# 2               Low             2  ...         Corporate        Technology
# 3               Low             2  ...         Corporate        Technology
# 4               Low             2  ...         Corporate   Office Supplies
# ...             ...           ...  ...               ...               ...
# 8394       Critical             5  ...         Corporate   Office Supplies
# 8395       Critical             5  ...    Small Business   Office Supplies
# 8396       Critical             5  ...       Home Office        Technology
# 8397       Critical             5  ...         Corporate        Technology
# 8398       Critical             5  ...         Corporate   Office Supplies
#
#                 Product Sub-Category  \
# 0             Storage & Organization
# 1                              Paper
# 2       Telephones and Communication
# 3       Telephones and Communication
# 4     Binders and Binder Accessories
# ...                              ...
# 8394             Pens & Art Supplies
# 8395                      Appliances
# 8396    Telephones and Communication
# 8397            Computer Peripherals
# 8398          Storage & Organization
#
#                                            Product Name Product Container  \
# 0      Eldon Base for stackable storage shelf, platinum         Large Box
# 1                                             Xerox 198         Small Box
# 2                                                  g520         Small Box
# 3                                                LX 788         Small Box
# 4     GBC Pre-Punched Binding Paper, Plastic, White,...         Small Box
# ...                                                 ...               ...
# 8394                      4009® Highlighters by Sanford          Wrap Bag
# 8395  Holmes Replacement Filter for HEPA Air Cleaner...        Jumbo Drum
# 8396                                               8890         Small Box
# 8397  80 Minute Slim Jewel Case CD-R , 10/Pack - Sta...        Small Pack
# 8398                  Fellowes Recycled Storage Drawers         Small Box
#
#       Product Base Margin  Ship Date            BirthDate   AGE DAYS
# 0                     0.8 2010-10-20  1970-04-08 00:00:00  50.0    7
# 1                    0.38 2010-02-26                   NA   NaN    0
# 2                    0.59 2012-04-22  1982-03-07 00:00:00  38.0    7
# 3                    0.58 2012-04-19  1982-09-20 00:00:00  38.0    4
# 4                    0.37 2011-03-11  1982-10-11 00:00:00  38.0    2
# ...                   ...        ...                  ...   ...  ...
# 8394                 0.52 2009-07-10  1973-06-10 00:00:00  47.0    1
# 8395                 0.41 2012-03-30  1956-06-22 00:00:00  64.0    1
# 8396                 0.58 2010-07-07  1972-10-27 00:00:00  48.0    0
# 8397                 0.52 2010-06-06  1971-09-08 00:00:00  49.0    1
# 8398                 0.78 2010-06-07  1971-07-04 00:00:00  49.0    2
#
# [8399 rows x 35 columns]
